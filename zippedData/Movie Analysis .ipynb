# %%
# numpy for numerical functions
import numpy as np
# pandas for analysis and data manipulation
import pandas as pd
# seaborn and pyplot for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# import sqlite3
import sqlite3

# %% [markdown]
# # Loading data

# %%
df = pd.read_csv('bom.movie_gross.csv')
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df1 = pd.read_csv('tmdb.movies.csv')
df1
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
df2 = pd.read_csv('tn.movie_budgets.csv')
df2
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
df3 = pd.read_csv('rt.movie_info.tsv', sep = '\t')
df3
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
df4 = pd.read_csv('rt.reviews.tsv', sep ='\t',encoding ='latin1')
df4
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %% [markdown]
# # Data Understanding.

# %% [markdown]
# Rename the movie column names to a similar name.
# Then combine both tables using the movie name.

# %%
# column names of the table that has been merged
df.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
df.shape
# Out:
# (3387, 5)

# %%
# summary statistics for each column
df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
# a decription of the information in the table
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
# The first 5 rows of the table
df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# The last 5 rows of the table
df.tail()
# Out:
#                             title      studio  domestic_gross foreign_gross  \
# 3382                    The Quake       Magn.          6200.0           NaN
# 3383  Edward II (2018 re-release)          FM          4800.0           NaN
# 3384                     El Pacto        Sony          2500.0           NaN
# 3385                     The Swan  Synergetic          2400.0           NaN
# 3386            An Actor Prepares       Grav.          1700.0           NaN
#
#       year
# 3382  2018
# 3383  2018
# 3384  2018
# 3385  2018
# 3386  2018

# %%
df.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %%
df = df.applymap(lambda x: str(x))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3387 non-null   object
#  2   domestic_gross  3387 non-null   object
#  3   foreign_gross   3387 non-null   object
#  4   year            3387 non-null   object
# dtypes: object(5)
# memory usage: 132.4+ KB

# %% [markdown]
# Relationship betweenn the variables.

# %% [markdown]
# # Data Cleaning.

# %%
# rename original_title to movie.
df1.rename(columns={'original_title': 'movie'}, inplace = True)
df1
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                               movie  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
# merge the two tables df1 and df2 on the common column name 'movie'
df = pd.merge(df1,df2, on = 'movie',how = 'inner')
df
# Out:
#       Unnamed: 0            genre_ids    id_x original_language  \
# 0              1  [14, 12, 16, 10751]   10191                en
# 1              2        [12, 28, 878]   10138                en
# 2              3      [16, 35, 10751]     862                en
# 3           2473      [16, 35, 10751]     862                en
# 4              4        [28, 878, 12]   27205                en
# ...          ...                  ...     ...               ...
# 2311       26323                   []  509316                en
# 2312       26425              [10402]  509306                en
# 2313       26092             [35, 16]  546674                en
# 2314       26322                   []  513161                en
# 2315       26508                 [16]  514492                en
#
#                          movie  popularity release_date_x  \
# 0     How to Train Your Dragon      28.734     2010-03-26
# 1                   Iron Man 2      28.515     2010-05-07
# ...

# %%
# drop columns with insignificant information.
df = df.drop(columns = ['Unnamed: 0','release_date_y','id_x','title','genre_ids'])
df
# Out:
#      original_language                     movie  popularity release_date_x  \
# 0                   en  How to Train Your Dragon      28.734     2010-03-26
# 1                   en                Iron Man 2      28.515     2010-05-07
# 2                   en                 Toy Story      28.005     1995-11-22
# 3                   en                 Toy Story      28.005     1995-11-22
# 4                   en                 Inception      27.920     2010-07-16
# ...                ...                       ...         ...            ...
# 2311                en                   The Box       0.600     2018-03-04
# 2312                en                   The Box       0.600     2018-03-04
# 2313                en                    Enough       0.719     2018-03-22
# 2314                en              Undiscovered       0.600     2018-04-07
# 2315                en                      Jaws       0.600     2018-05-29
#
# ...

# %%
# Total number of null values in all the columns
df.isnull().sum()
# Out:
# original_language    0
# movie                0
# popularity           0
# release_date_x       0
# vote_average         0
# vote_count           0
# id_y                 0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
# Check for missing values in the table
df.isna().sum()
# Out:
# original_language    0
# movie                0
# popularity           0
# release_date_x       0
# vote_average         0
# vote_count           0
# id_y                 0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
# check for duplicate values
df.duplicated().sort_values().sum()
# Out:
# 172

# %%
# drop the duplicate values and keep the first
df.drop_duplicates(subset = ['movie'], keep = 'first', inplace = True)

# %%
# counter-check on the duplicate values
df.duplicated().sort_values().sum()
# Out:
# 0

# %%
# view the table with no duplicates
df
# Out:
#      original_language                                              movie  \
# 0                   en                           How to Train Your Dragon
# 1                   en                                         Iron Man 2
# 2                   en                                          Toy Story
# 4                   en                                          Inception
# 5                   en  Percy Jackson & the Olympians: The Lightning T...
# ...                ...                                                ...
# 2308                en                                              Molly
# 2309                en                                            The Box
# 2313                en                                             Enough
# 2314                en                                       Undiscovered
# 2315                en                                               Jaws
#
#       popularity release_date_x  vote_average  vote_count  id_y  \
# ...

# %%
# remove the $ 'dollar sign' and ',' from the production_budget column
# convert production_budget to an integer
df['production_budget'] = df['production_budget'].replace({'\$':'',',':''},regex = True)
df['production_budget'].astype(str).astype(int)
# Out:
# 0       165000000
# 1       170000000
# 2        30000000
# 4       160000000
# 5        95000000
#           ...
# 2308     21000000
# 2309     25000000
# 2313     38000000
# 2314      9000000
# 2315     12000000
# Name: production_budget, Length: 1908, dtype: int32

# %%
# remove the $ 'dollar sign' and ',' from the domestic_gross column
# convert domestic_gross to an integer
df['domestic_gross'] = df['domestic_gross'].replace({'\$':'',',':''},regex = True)
df['domestic_gross'].astype(str).astype(int)
# Out:
# 0       217581232
# 1       312433331
# 2       191796233
# 4       292576195
# 5        88768303
#           ...
# 2308        17396
# 2309     15051977
# 2313     39177215
# 2314      1069318
# 2315    260000000
# Name: domestic_gross, Length: 1908, dtype: int32

# %%
df['worldwide_gross'] = df['worldwide_gross'].replace({'\$':'',',':''},regex = True)
df['worldwide_gross']
# Out:
# 0       494870992
# 1       621156389
# 2       364545516
# 4       835524642
# 5       223050874
#           ...
# 2308        17396
# 2309     34356760
# 2313     50970660
# 2314      1069318
# 2315    470700000
# Name: worldwide_gross, Length: 1908, dtype: object

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# 1. Categorical Data

# %%
#arrange the domestic gross in order from the highest to the least.
top_domestic_gross = df.sort_values(['domestic_gross'], ascending =[False])
top_domestic_gross.head(10)
# Out:
#      original_language               movie  popularity release_date_x  \
# 2232                en   Christopher Robin      20.931     2018-08-03
# 937                 en  Olympus Has Fallen      13.864     2013-03-22
# 350                 en    The Green Hornet      14.501     2011-01-13
# 65                  en          Date Night      12.498     2010-04-08
# 1234                en          Camp X-Ray      15.237     2014-10-17
# 188                 en       Meek's Cutoff       7.309     2010-10-08
# 1817                en       Sausage Party      15.232     2016-08-12
# 141                 en      Blue Valentine       8.994     2010-12-29
# 514                 en          The Beaver       7.357     2011-05-05
# 32                  en  The Social Network      15.889     2010-10-01
#
#       vote_average  vote_count  id_y production_budget domestic_gross  \
# 2232           7.4        1280    43          75000000       99215042
# ...

# %%
# arrange the worldwide_gross in order from the highest to the least 
top_worldwide_gross = df.sort_values('worldwide_gross', ascending = False)
top_worldwide_gross.head(10)
# Out:
#      original_language                           movie  popularity  \
# 330                 en                       Insidious      16.197
# 1993                en      Thank You for Your Service       0.600
# 2216                en                           Alpha      24.536
# 477                 en  Justin Bieber: Never Say Never       8.602
# 1011                en                       Philomena       8.978
# 1524                en                      Black Mass      14.646
# 2298                ur                Teefa in Trouble       4.486
# 1571                en                       The Visit      10.196
# 311                 en                   The Lion King      28.583
# 704                 en                      Contraband      12.357
#
#      release_date_x  vote_average  vote_count  id_y production_budget  \
# 330      2011-04-01           6.9        3582    63           1500000
# 1993     2016-09-16           6.0           1    48          20000000
# ...

# %%
# extract the two columns production budget and domestic gross from the dataset
subs =df.iloc[:,7:9]
subs
# Out:
#      production_budget domestic_gross
# 0            165000000      217581232
# 1            170000000      312433331
# 2             30000000      191796233
# 4            160000000      292576195
# 5             95000000       88768303
# ...                ...            ...
# 2308          21000000          17396
# 2309          25000000       15051977
# 2313          38000000       39177215
# 2314           9000000        1069318
# 2315          12000000      260000000
#
# [1908 rows x 2 columns]

# %%
# convert the values in production budget and domestic gross to integers
subs['production_budget'] = subs['production_budget'].astype(int)
subs['domestic_gross'] = subs['domestic_gross'].astype(int)

# %%
# Subtract the production budget from domestic gross to get the profit margin. 
df['profit_margin'] = subs['domestic_gross'] - subs['production_budget']
df['profit_margin']
# Out:
# 0        52581232
# 1       142433331
# 2       161796233
# 4       132576195
# 5        -6231697
#           ...
# 2308    -20982604
# 2309     -9948023
# 2313      1177215
# 2314     -7930682
# 2315    248000000
# Name: profit_margin, Length: 1908, dtype: int32

# %%
# arrange the profit margin from the highest 
df = df.sort_values(by ='profit_margin', ascending = False)
df.head(10)
# Out:
#      original_language                         movie  popularity  \
# 567                 en                 Black Panther       2.058
# 1478                en                Jurassic World      20.709
# 2190                en                 Incredibles 2      36.286
# 632                 en                  The Avengers      50.289
# 2182                en        Avengers: Infinity War      80.773
# 613                 en               The Dark Knight       0.600
# 635                 en          Beauty and the Beast      26.701
# 311                 en                 The Lion King      28.583
# 6                   en                        Avatar      26.526
# 1770                en  Rogue One: A Star Wars Story      21.401
#
#      release_date_x  vote_average  vote_count  id_y production_budget  \
# 567      2011-01-18           5.1          11    42         200000000
# 1478     2015-06-12           6.6       14056    34         215000000
# ...

# %%
# description of the dataset
df.describe()
# Out:
#         popularity  vote_average    vote_count         id_y  profit_margin
# count  1908.000000   1908.000000   1908.000000  1908.000000   1.908000e+03
# mean     10.724768      6.163574   1657.409329    50.736897   1.016612e+07
# std       7.990080      1.136877   2631.848991    28.591108   5.571628e+07
# min       0.600000      0.000000      1.000000     1.000000  -2.019413e+08
# 25%       5.967000      5.600000     77.750000    26.000000  -1.000000e+07
# 50%       9.515000      6.200000    618.500000    51.000000  -7.854685e+05
# 75%      14.343000      6.900000   2036.000000    76.000000   1.793705e+07
# max      80.773000     10.000000  22186.000000   100.000000   5.000596e+08

# %%
# extract rows whereby the vote average, vote count and profit margin values are above the 75% percentile
df1 = df.loc[(df['vote_average'] > 6.9) & (df['vote_count'] > 2036) & (df['profit_margin']>17937050)]
df1.head(10)
# Out:
#      original_language                            movie  popularity  \
# 311                 en                    The Lion King      28.583
# 59                  en                         Kick-Ass      13.080
# 1471                en                         Southpaw      25.305
# 2204                en                    The Favourite      28.651
# 2214                en                   BlacKkKlansman      25.101
# 136                 en                    The Last Song       9.237
# 1515                en                        Spotlight      16.354
# 2189                en                Bohemian Rhapsody      37.197
# 2003                en           Spider-Man: Homecoming      46.775
# 891                 en  The Hunger Games: Catching Fire      20.187
#
#      release_date_x  vote_average  vote_count  id_y production_budget  \
# 311      1994-06-23           8.2       10160     9          79300000
# 59       2010-04-16           7.1        7540    54          28000000
# ...

# %% [markdown]
# # Data Visualization

# %%
# plot a bar graph that shows the profit margins against the movie titles.
fig = plt.figure(figsize= (13,8))
movie = df1['movie'].head(10)
profit_margin = df1['profit_margin'].head(10)
# creating the bar graph
plt.bar(movie, profit_margin, width= 0.5)
plt.xlabel('movies')
plt.ylabel('profit_margin*(10^7)')
plt.title('The profit margins in the top 10 films')
plt.xticks(rotation = 90)
plt.show()

# %%
# plot a bar graph that shows the production budget budget against the top 10 films
fig = plt.figure(figsize= (13,7))
movie = df1['movie'].head(10)
production_budget = df1['production_budget'].head(10)
# creating the bar graph
plt.bar(movie,production_budget, width= 0.6)
plt.xlabel('movie')
plt.ylabel('production_budget')
plt.title('Production budget against the top ten movies')
plt.xticks(rotation = 90)
plt.show()

# %%
# graph on the relationship between the the vote average and worldwide gross 
# this determines how they relate
fig = plt.figure(figsize= (13,7))
ratings = df['vote_average'].head(20)
worldwide_gross = df['worldwide_gross'].head(20)
# creating the bar graph
plt.bar(worldwide_gross,ratings, width= 0.5)
plt.xlabel('worldwide_gross')
plt.ylabel('vote average')
plt.title('Ratings against worldwide gross')
plt.xticks(rotation = 90)
plt.show();

# %%
plt.figure(figsize=(15,8))

df['vote_average'].head(100).hist(bins=30)
plt.xlabel('Vote Average')
plt.ylabel('Frequency')
plt.title('Distribution of Vote Average');
