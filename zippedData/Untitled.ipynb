# %%
# numpy for numerical functions
import numpy as np
# pandas for analysis and data manipulation
import pandas as pd
# seaborn and pyplot for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# import sqlite3
import sqlite3

# %%
df = pd.read_csv('bom.movie_gross.csv')
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df1 = pd.read_csv('tmdb.movies.csv')
df1
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
df2 = pd.read_csv('tn.movie_budgets.csv')
df2
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
df3 = pd.read_csv('rt.movie_info.tsv', sep = '\t')
df3
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
df4 = pd.read_csv('rt.reviews.tsv', sep ='\t',encoding ='latin1')
df4
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %% [markdown]
# # Cleaning the table.

# %% [markdown]
# Rename the movie column names to a similar name.
# Then combine both tables using the movie name.

# %%
# rename original_title to movie.
df1.rename(columns={'original_title': 'movie'}, inplace = True)
df1
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                               movie  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
# merge the two tables df1 and df2 on the common column name movie
df = pd.merge(df1,df2, on = 'movie',how = 'inner')
df
# Out:
#       Unnamed: 0            genre_ids    id_x original_language  \
# 0              1  [14, 12, 16, 10751]   10191                en
# 1              2        [12, 28, 878]   10138                en
# 2              3      [16, 35, 10751]     862                en
# 3           2473      [16, 35, 10751]     862                en
# 4              4        [28, 878, 12]   27205                en
# ...          ...                  ...     ...               ...
# 2311       26323                   []  509316                en
# 2312       26425              [10402]  509306                en
# 2313       26092             [35, 16]  546674                en
# 2314       26322                   []  513161                en
# 2315       26508                 [16]  514492                en
#
#                          movie  popularity release_date_x  \
# 0     How to Train Your Dragon      28.734     2010-03-26
# 1                   Iron Man 2      28.515     2010-05-07
# ...

# %%
# column names of the table that has been merged
df.columns
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id_x', 'original_language', 'movie',
#        'popularity', 'release_date_x', 'title', 'vote_average', 'vote_count',
#        'id_y', 'release_date_y', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %%
df.shape
# Out:
# (2316, 15)

# %%
# drop columns with insignificant information.
df = df.drop(columns = ['Unnamed: 0','release_date_y','id_x','title','genre_ids'])
df
# Out:
#      original_language                     movie  popularity release_date_x  \
# 0                   en  How to Train Your Dragon      28.734     2010-03-26
# 1                   en                Iron Man 2      28.515     2010-05-07
# 2                   en                 Toy Story      28.005     1995-11-22
# 3                   en                 Toy Story      28.005     1995-11-22
# 4                   en                 Inception      27.920     2010-07-16
# ...                ...                       ...         ...            ...
# 2311                en                   The Box       0.600     2018-03-04
# 2312                en                   The Box       0.600     2018-03-04
# 2313                en                    Enough       0.719     2018-03-22
# 2314                en              Undiscovered       0.600     2018-04-07
# 2315                en                      Jaws       0.600     2018-05-29
#
# ...

# %% [markdown]
# # Data Understanding

# %%
# summary statistics for each column
df.describe()
# Out:
#         popularity  vote_average    vote_count         id_y
# count  2316.000000   2316.000000   2316.000000  2316.000000
# mean     10.685747      6.206261   1712.143351    50.842832
# std       8.244311      1.178079   2704.578576    28.359866
# min       0.600000      0.000000      1.000000     1.000000
# 25%       5.487000      5.600000     63.000000    27.000000
# 50%       9.506000      6.300000    615.000000    51.000000
# 75%      14.423750      6.900000   2100.500000    75.000000
# max      80.773000     10.000000  22186.000000   100.000000

# %%
# a decription of the information in the table
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2316 entries, 0 to 2315
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_language  2316 non-null   object
#  1   movie              2316 non-null   object
#  2   popularity         2316 non-null   float64
#  3   release_date_x     2316 non-null   object
#  4   vote_average       2316 non-null   float64
#  5   vote_count         2316 non-null   int64
#  6   id_y               2316 non-null   int64
#  7   production_budget  2316 non-null   object
#  8   domestic_gross     2316 non-null   object
#  9   worldwide_gross    2316 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 199.0+ KB

# %%
# The first 5 rows of the table
df.head()
# Out:
#   original_language                     movie  popularity release_date_x  \
# 0                en  How to Train Your Dragon      28.734     2010-03-26
# 1                en                Iron Man 2      28.515     2010-05-07
# 2                en                 Toy Story      28.005     1995-11-22
# 3                en                 Toy Story      28.005     1995-11-22
# 4                en                 Inception      27.920     2010-07-16
#
#    vote_average  vote_count  id_y production_budget domestic_gross  \
# 0           7.7        7610    30      $165,000,000   $217,581,232
# 1           6.8       12368    15      $170,000,000   $312,433,331
# 2           7.9       10174    37       $30,000,000   $191,796,233
# 3           7.9       10174    37       $30,000,000   $191,796,233
# 4           8.3       22186    38      $160,000,000   $292,576,195
#
#   worldwide_gross
# 0    $494,870,992
# 1    $621,156,389
# 2    $364,545,516
# 3    $364,545,516
# 4    $835,524,642

# %%
# The last 5 rows of the table
df.tail()
# Out:
#      original_language         movie  popularity release_date_x  vote_average  \
# 2311                en       The Box       0.600     2018-03-04           8.0
# 2312                en       The Box       0.600     2018-03-04           6.0
# 2313                en        Enough       0.719     2018-03-22           8.7
# 2314                en  Undiscovered       0.600     2018-04-07           8.0
# 2315                en          Jaws       0.600     2018-05-29           0.0
#
#       vote_count  id_y production_budget domestic_gross worldwide_gross
# 2311           1    66       $25,000,000    $15,051,977     $34,356,760
# 2312           1    66       $25,000,000    $15,051,977     $34,356,760
# 2313           3    68       $38,000,000    $39,177,215     $50,970,660
# 2314           1     7        $9,000,000     $1,069,318      $1,069,318
# 2315           1    41       $12,000,000   $260,000,000    $470,700,000

# %%
df.dtypes
# Out:
# original_language     object
# movie                 object
# popularity           float64
# release_date_x        object
# vote_average         float64
# vote_count             int64
# id_y                   int64
# production_budget     object
# domestic_gross        object
# worldwide_gross       object
# dtype: object

# %%
df = df.applymap(lambda x: str(x))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2316 entries, 0 to 2315
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_language  2316 non-null   object
#  1   movie              2316 non-null   object
#  2   popularity         2316 non-null   object
#  3   release_date_x     2316 non-null   object
#  4   vote_average       2316 non-null   object
#  5   vote_count         2316 non-null   object
#  6   id_y               2316 non-null   object
#  7   production_budget  2316 non-null   object
#  8   domestic_gross     2316 non-null   object
#  9   worldwide_gross    2316 non-null   object
# dtypes: object(10)
# memory usage: 199.0+ KB

# %%
# convert production_budget to an integer
df['production_budget'] = df['production_budget'].replace({'\$':'',',':''},regex = True)
df['production_budget'].astype(str).astype(int)
# Out:
# 0       165000000
# 1       170000000
# 2        30000000
# 3        30000000
# 4       160000000
#           ...
# 2311     25000000
# 2312     25000000
# 2313     38000000
# 2314      9000000
# 2315     12000000
# Name: production_budget, Length: 2316, dtype: int32

# %%
# convert domestic_gross to an integer
df['domestic_gross'] = df['domestic_gross'].replace({'\$':'',',':''},regex = True)
df['domestic_gross'].astype(str).astype(int)
# Out:
# 0       217581232
# 1       312433331
# 2       191796233
# 3       191796233
# 4       292576195
#           ...
# 2311     15051977
# 2312     15051977
# 2313     39177215
# 2314      1069318
# 2315    260000000
# Name: domestic_gross, Length: 2316, dtype: int32

# %% [markdown]
# Relationship betweenn the variables.

# %% [markdown]
# # Data Preparation.

# %%
# Total number of null values in all the columns
df.isnull().sum()
# Out:
# original_language    0
# movie                0
# popularity           0
# release_date_x       0
# vote_average         0
# vote_count           0
# id_y                 0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
# Check for missing values in the table
df.isna().sum()
# Out:
# original_language    0
# movie                0
# popularity           0
# release_date_x       0
# vote_average         0
# vote_count           0
# id_y                 0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
# check for duplicate values
df.duplicated().sort_values().sum()
# Out:
# 172

# %%
df.drop_duplicates(subset = ['movie'], keep = 'first', inplace = True)

# %%
df.duplicated().sort_values().sum()
# Out:
# 0

# %%
df
# Out:
#      original_language                                              movie  \
# 0                   en                           How to Train Your Dragon
# 1                   en                                         Iron Man 2
# 2                   en                                          Toy Story
# 4                   en                                          Inception
# 5                   en  Percy Jackson & the Olympians: The Lightning T...
# ...                ...                                                ...
# 2308                en                                              Molly
# 2309                en                                            The Box
# 2313                en                                             Enough
# 2314                en                                       Undiscovered
# 2315                en                                               Jaws
#
#      popularity release_date_x vote_average vote_count id_y production_budget  \
# ...

# %%
x1 = df['domestic_gross']
x2 = df['production_budget']

plt.figure(figsize =(13,5))
plt.hist([x1,x2],label=['domestic_gross','production_budget'], bins=10, alpha = 0.5)
plt.legend(borderpad=0.5, fontsize=20)
plt.show()

# %% [markdown]
# # Univariate EDA

# %%
#arrange the domestic gross in order from the highest to the least.
top_domestic_gross = df.sort_values(['domestic_gross'], ascending =[False])
top_domestic_gross.head(10)
# Out:
#      original_language               movie popularity release_date_x  \
# 2232                en   Christopher Robin     20.931     2018-08-03
# 937                 en  Olympus Has Fallen     13.864     2013-03-22
# 350                 en    The Green Hornet     14.501     2011-01-13
# 65                  en          Date Night     12.498     2010-04-08
# 1234                en          Camp X-Ray     15.237     2014-10-17
# 188                 en       Meek's Cutoff      7.309     2010-10-08
# 1817                en       Sausage Party     15.232     2016-08-12
# 141                 en      Blue Valentine      8.994     2010-12-29
# 514                 en          The Beaver      7.357     2011-05-05
# 32                  en  The Social Network     15.889     2010-10-01
#
#      vote_average vote_count id_y production_budget domestic_gross  \
# 2232          7.4       1280   43          75000000       99215042
# 937           6.2       4086    9          70000000       98927592
# ...

# %%
# arrange the worldwide_gross in order from the highest to the least 
top_worldwide_gross = df.sort_values(['worldwide_gross'], ascending =[False])
top_worldwide_gross.head(10)
# Out:
#      original_language                           movie popularity  \
# 330                 en                       Insidious     16.197
# 2216                en                           Alpha     24.536
# 477                 en  Justin Bieber: Never Say Never      8.602
# 311                 en                   The Lion King     28.583
# 1011                en                       Philomena      8.978
# 1524                en                      Black Mass     14.646
# 2298                ur                Teefa in Trouble      4.486
# 1571                en                       The Visit     10.196
# 704                 en                      Contraband     12.357
# 2027                en                   Atomic Blonde     21.662
#
#      release_date_x vote_average vote_count id_y production_budget  \
# 330      2011-04-01          6.9       3582   63           1500000
# 2216     2018-08-17          5.9       1167   79          51000000
# ...

# %%
df.describe()
# Out:
#        original_language                     movie popularity release_date_x  \
# count               1908                      1908       1908           1908
# unique                25                      1908       1700            959
# top                   en  How to Train Your Dragon        0.6     2015-10-16
# freq                1844                         1        101             10
#
#        vote_average vote_count  id_y production_budget domestic_gross  \
# count          1908       1908  1908              1908           1908
# unique           70       1250   100               291           1674
# top             6.1          1    33          10000000              0
# freq             95         84    26                74            233
#
#        worldwide_gross
# count             1908
# unique            1744
# top                 $0
# freq               163

# %% [markdown]
# # Data Visualization

# %%
# 
fig = plt.figure(figsize= (13,5))
domestic_gross = df['domestic_gross']
production_budget = df['production_budget']
# creating the bar graph
plt.bar(domestic_gross,production_budget, width= 0.5)
plt.xlabel('domestic_gross')
# Out:
# Text(0.5, 0, 'domestic_gross')
